# %%
l=["py","python2","pyt","python"]
l.sort(reverse=True)
ans=""
for i in range(len(l[-1])):
    if l[0][i]==l[-1][i]:
        ans=ans+l[-1][i]
        continue
    else:
        break
print(ans)
# Out:
# py

# %%
l=[10,14,15,9,121,189,100]
for i in l:
    if i>10:
        i=str(i)
        if int(i[0])%2!=0 and int(i[-1])%2!=0:
            print(i)
# Out:
# 15
# 121
# 189

# %%
l=[1,2,3,7,8]
z=[]
for i in range (len(l)):
    z.append(l[i])
    z.append(7)
z.pop()    
print(z)
# Out:
# [1, 7, 2, 7, 3, 7, 7, 7, 8]

# %%
z=[]
i=0
while i<len(t):
    if i%2==0:
        z.append(max(l))
        l.remove(max(l))
        i=i+1
    else:
        z.append(min(l))
        l.remove(min(l))
        i=i+1 
print(z)
# Out:
# [31, 1, 11, 2, 9, 7]

# %%
#dictionary
x={"name":"Angel","age":18,"city":"ahm"}
x["name"]="adroja"
x["Name"]="ang"
print(x)
z={}
a=input("Enter key: ")
b=input("Enter value: ")
z[a]=b
print(z)
# Out:
# {'name': 'adroja', 'age': 18, 'city': 'ahm', 'Name': 'ang'}
# Enter key: id
# Enter value: 3
# {'id ': '3'}

# %%
x={"name":"Angel","t1":18,"t2":21,"t3":21,"t4":22}
print(x["t1"])
del x["t2"]
print(x)
x.keys()
x.values()
x.items()
for i,j in x.items():
    print(i,j)
# Out:
# 18
# {'name': 'Angel', 't1': 18, 't3': 21, 't4': 22}
# name Angel
# t1 18
# t3 21
# t4 22

# %%
z={}
for i in range (3):
    n=input("Enter Cicketer name:")
    score=int(input("Enter score: "))
    z[n]=score
print(z)  
print("max",max(z.values()))
print("min",min(z.values()))
print("sum",sum(z.values()))
print("avg",sum//3)
for i,j in z.items():
    print(i,"score is",j)
# Out:
# Enter Cicketer name:a
# Enter score: 1
# Enter Cicketer name:s
# Enter score: 2
# Enter Cicketer name:d
# Enter score: 3
# {'a': 1, 's': 2, 'd': 3}
# max 3
# min 1
# sum 6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-e7c17dfc2822> in <module>
#       8 print("min",min(z.values()))
#       9 print("sum",sum(z.values()))
# ---> 10 print("avg",sum//3)
#      11 for i,j in z.items():
#      12     print(i,"score is",j)
#
# TypeError: unsupported operand type(s) for //: 'builtin_function_or_method' and 'int'
