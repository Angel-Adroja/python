# %%
#password
n1=input("Enter string: ")
n=len(n1)
u=0
l=0
s=0
d=0
e=1
a=0
if n>8 :
        for i in n1:
            if i.isupper():
                u=u+1
            elif i.islower():
                l=l+1
            elif i.isspace():
                s=s+1 
            elif i.isdigit():
                d=d+1
            else:
                e=e+1
                
        if u>=1 and l>=1 and s<=0:
            print("valid") 
        else:
            print("Invalid")
        
else:
        print("Inavlid")
# Out:
# Enter string: nmvAS@@!12
# valid

# %%
x="hi hello by angel python"
y=x.split(" ")
print(y)
for i in y:
    if len(i)%2!=0:
        print(i[ : :-1])
# Out:
# ['hi', 'hello', 'by', 'angel', 'python']
# olleh
# legna

# %%
x="hi hello by angel python"
y=x.split(" ")
if i[0]==i[-1]:
    print(i)
# Out:
# 2

# %%
x="hi hello by Angel pythona"
y=x.split(" ")
c=0
for i in y:
    if i.count("a") or i.count("A"):
        c=c+1 
    if c>1: 
        print(i)
# Out:
# pythona

# %%
#shifting
x=input("Enter Number: ")
x1=len(x)
n=input("Enter shift number: ")
n1=len(n)
y=x[n1:x1]
print(y)
# Out:
# Enter Number: 12345
# Enter shift number: 2
# 345

# %%
#remove position

# %%
x=input("Enter string: ")
sum=0
c=0
for i in x:
    if i.isnumeric():
        sum=sum+i
        c=c+1
print(sum/c)
# Out:
# Enter string: 52452jk
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-38e3b9315a7c> in <module>
#       4 for i in x:
#       5     if i.isnumeric():
# ----> 6         sum=sum+i
#       7         c=c+1
#       8 print(sum/c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
x=input("Enter string: ")
y=x.split(" ")
for i in y:
    a=i[0].upper()+x[1:2]+x[-1].upper()
    p
# Out:
# Enter string: ghjvb
