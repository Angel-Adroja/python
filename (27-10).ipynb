# %%
x="Happy new year ram ram"
x[0]
x[-1]
x[0:9: ]
x[ : :2]
x[0:12:2]
x[-1:-6:-1]
x[-1:6]
x[-1:-3:]
x[1:10:-1]
x[1:-2]
x[1:-2:-1]
x[ : :-1]
x[ :2:5]
x[10: :10]
x[-6:-1]
x[-1:5:-1]
# Out:
# 'mar mar raey wen'

# %%
#palidrom
n=input("Enter String: ")
if n[ : : ]==n[ : :-1]:
    print(n[0: :2])
else:
    print(n[1: :2])
# Out:
# Enter String: 12321
# 131

# %%
x="hi hello How are you hello"
x.count("h")
x.count("h",0,2)
x.swapcase()
x.upper()
x.lower()
x.count("hello",0,6)
x.count("hello",0,10)
# Out:
# 1

# %%
x=input("Enter String: ")
if n.count("a")%2==0:
    print(x.count("a"))
    print(x.upper())
else:
    print(x.count("a"))
    print(x.upper())
# Out:
# Enter String: angel adroja
# 3
# ANGEL ADROJA

# %%
x=input("Enter String: ")
y=x.split(" ")
print(y)
# Out:
# Enter String: dhruv virat dhomi
# ['dhruv', 'virat', 'dhomi']

# %%
x=input("Enter String: ")
y=x.split(" ")
print(y)
z="=".join(y)
print(z)
# Out:
# Enter String: hi hello hi
# ['hi', 'hello', 'hi']
# hi=hello=hi

# %%
x=input("Enter String: ")
print(len(x))
y=x.split(" ")
print(len(y))
for i in  y:
    print(i[ : :-1])
# Out:
# Enter String: hi hello hi
# 11
# 3
# ih
# olleh
# ih
